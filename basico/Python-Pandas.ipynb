# %% [markdown]
# ![python.png](attachment:python.png)

# %% [markdown]
# # Python com Pandas

# %%
import pandas as pd

# %%
## Lendo Dados
df = pd.read_csv("../bases/Automobile_data.csv")

# %% [markdown]
# ![dataset-cover.jpg](attachment:dataset-cover.jpg)

# %% [markdown]
# Este é um conjunto de dados consiste extraído da revista <b>1985 Year's Automotive Yearbook</b>.
# <ol>
#  <li>Especificações de carros e caminhões importados modelo de 1985.</li>
#  <li>Manuais de automóveis pessoais, escritório de serviços de seguros, 160 Water Street, Nova York, NY 10038</li>
#  <li>Relatório de Colisão de Seguros, Instituto de Seguros para Segurança nas Rodovias, Watergate 600, Washington, DC 20037</li>
# </ol>

# %%
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.tail(5)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %% [markdown]
# ## Limpar e alterar o arquivo CSV

# %%
# Antes
print('ANTES:', df.isnull().sum())
df = pd.read_csv("../bases/Automobile_data.csv", na_values={
    'stroke':["?", "n.a"],
    'horsepower':["?", "n.a"],
    'peak-rpm':["?", "n.a"],
    'price':["?", "n.a"],
    'average-mileage':["?", "n.a"]
})
df.to_csv("../bases/Automobile_data_update.csv")
# Depois
df2 = pd.read_csv("../bases/Automobile_data_update.csv")
print('DEPOIS:', df2.isnull().sum())
# Out:
# ANTES: symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64
# DEPOIS: Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# ...
