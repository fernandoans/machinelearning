# %% [markdown]
# ![Data-ScientistsCovid.png](attachment:Data-ScientistsCovid.png)

# %% [markdown]
# # COVID-19

# %%
# Bibliotecas Necessárias
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Dados dos Casos

# %%
# Base disponível em: https://github.com/CSSEGISandData/COVID-19

casos = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
casos.tail()
# Out:
#                 Province/State         Country/Region        Lat       Long  \
# 259  Saint Pierre and Miquelon                 France  46.885200 -56.315900
# 260                        NaN            South Sudan   6.877000  31.307000
# 261                        NaN         Western Sahara  24.215500 -12.885800
# 262                        NaN  Sao Tome and Principe   0.186360   6.613081
# 263                        NaN                  Yemen  15.552727  48.516388
#
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/5/20  \
# 259        0        0        0        0        0        0  ...       1
# 260        0        0        0        0        0        0  ...       1
# 261        0        0        0        0        0        0  ...       4
# 262        0        0        0        0        0        0  ...       0
# 263        0        0        0        0        0        0  ...       0
#
#      4/6/20  4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  4/12/20  4/13/20  \
# ...

# %% [markdown]
# ## Casos no Brasil

# %%
casosBrasil = casos[casos['Country/Region'] == 'Brazil']
valCasosBrasil = np.sum(casosBrasil.iloc[ : , 4 : casosBrasil.shape[1]])
valCasosBrasil.plot()

# %%
casosBrasil.head()
# Out:
#    Province/State Country/Region     Lat     Long  1/22/20  1/23/20  1/24/20  \
# 28            NaN         Brazil -14.235 -51.9253        0        0        0
#
#     1/25/20  1/26/20  1/27/20  ...  3/29/20  3/30/20  3/31/20  4/1/20  4/2/20  \
# 28        0        0        0  ...     4256     4579     5717    6836    8044
#
#     4/3/20  4/4/20  4/5/20  4/6/20  4/7/20
# 28    9056   10360   11130   12161   14034
#
# [1 rows x 81 columns]

# %% [markdown]
# ## Obituários

# %%
mortes = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
mortes.tail()
# Out:
#                 Province/State         Country/Region        Lat       Long  \
# 259  Saint Pierre and Miquelon                 France  46.885200 -56.315900
# 260                        NaN            South Sudan   6.877000  31.307000
# 261                        NaN         Western Sahara  24.215500 -12.885800
# 262                        NaN  Sao Tome and Principe   0.186360   6.613081
# 263                        NaN                  Yemen  15.552727  48.516388
#
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/5/20  \
# 259        0        0        0        0        0        0  ...       0
# 260        0        0        0        0        0        0  ...       0
# 261        0        0        0        0        0        0  ...       0
# 262        0        0        0        0        0        0  ...       0
# 263        0        0        0        0        0        0  ...       0
#
#      4/6/20  4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  4/12/20  4/13/20  \
# ...

# %% [markdown]
# ## Obituários no Brasil

# %%
mortesBrasil = mortes[mortes['Country/Region'] == 'Brazil']
valMortesBrasil = np.sum(mortesBrasil.iloc[ : , 4 : mortesBrasil.shape[1]])
valMortesBrasil.plot()

# %%
mortesBrasil.tail()
# Out:
#    Province/State Country/Region     Lat     Long  1/22/20  1/23/20  1/24/20  \
# 28            NaN         Brazil -14.235 -51.9253        0        0        0
#
#     1/25/20  1/26/20  1/27/20  ...  4/5/20  4/6/20  4/7/20  4/8/20  4/9/20  \
# 28        0        0        0  ...     486     564     686     819     950
#
#     4/10/20  4/11/20  4/12/20  4/13/20  4/14/20
# 28     1057     1124     1223     1328     1532
#
# [1 rows x 88 columns]

# %% [markdown]
# ## Cálculo da Taxa de Mortalidade no Brasil

# %%
mortalidade = (valMortesBrasil/valCasosBrasil)*100
mortalidade.plot()

# %% [markdown]
# ## Pacientes Recuperados

# %%
recuperados = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")
recuperados.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/5/20  4/6/20  4/7/20  4/8/20  4/9/20  \
# 0        0        0        0  ...      15      18      18      29      32
# 1        0        0        0  ...     104     116     131     154     165
# 2        0        0        0  ...      90      90     113     237     347
# 3        0        0        0  ...      26      31      39      52      58
# 4        0        0        0  ...       2       2       2       2       2
#
#    4/10/20  4/11/20  4/12/20  4/13/20  4/14/20
# ...

# %% [markdown]
# ## Pacientes Recuperados no Brasil

# %%
recuperadosBrasil = recuperados[recuperados['Country/Region'] == 'Brazil']
valRecuperadosBrasil = np.sum(recuperadosBrasil.iloc[ : , 4 : recuperadosBrasil.shape[1]])
valRecuperadosBrasil.plot()

# %% [markdown]
# ## Comparativo

# %%
casosAtivos = valCasosBrasil - (valRecuperadosBrasil + valMortesBrasil)
casosAtivos.plot()

# %%
df = pd.concat([valCasosBrasil, casosAtivos, valRecuperadosBrasil, valMortesBrasil], axis=1)
df.columns = (["casos", "ativos", "recuperados", "mortes"])
df.plot()

# %% [markdown]
# Até a próxima \
# Fernando Anselmo
