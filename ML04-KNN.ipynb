# %% [markdown]
# # Modelo "KNN - K Nearest Neighbors"
# Algorítimo supervisionado destinado a Predição por Clusterização

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import neighbors

# %matplotlib inline

# %% [markdown]
# ## Dados do Banco de Dados Íris

# %%
iris = datasets.load_iris() # Tam e Lrg da sépala e Tam e Lrg da pétala
X, y = iris.data, iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
# Treinar nosso modelo
clf = neighbors.KNeighborsClassifier()
clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))
# Out:
# 0.9666666666666667

# %%
predicao = clf.predict([[6.0, 3.3, 4.0, 1.3]])
print(predicao)
# Out:
# [1]

# %% [markdown]
# ## Compreendendo os Dados

# %%
# Usando os dois primeiros valores: Tam e Lrg da Sépala
cores = np.array(['green', 'red', 'blue'])
subplt1 = plt.scatter(x=X[:, 0], y=X[:, 1], c=cores[y], s=50)

# %% [markdown]
# Identificando as cores:
# Verde - Setosa, Vermelho - Versicolor e Azul - Virginica

# %% [markdown]
# ### Se quisessemos saber quem é esse ponto roxo?
# ![KNN_predicao.png](attachment:KNN_predicao.png)

# %%
# Usando os dois primeiros valores: Tam e Lrg da Pétala
cores = np.array(['green', 'red', 'blue'])
subplt1 = plt.scatter(x=X[:, 0], y=X[:, 1], c=cores[y], s=50)

# %%
predicao = clf.predict([[6.0, 3.5, 4.0, 2.0]])
print(predicao)
# Out:
# [1]

# %% [markdown]
# A saber: 0-Verde, 1-Vermelho e 2-Azul

# %% [markdown]
# Até a próxima \
# Fernando Anselmo
